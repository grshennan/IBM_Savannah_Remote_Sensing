# %% [markdown]
# ### Using Lidar to Determine Savannah Vegetation Characteristics

# %% [markdown]
# This is to report on the lidar collections at Yawuru 2024

# %% [markdown]
# 10 locations were sampled with lidar. Flight parameters were:
# - 50m altitude
# - 6m/s flight speed
# - 50% overlap
# - 5 returns

# %% [markdown]
# The 50% overlap parameter caused issues with later lidar thinning. This is discussed at length in the file XXXXX.
#
# The results of this are that the lidar overlap parameter should be set to either ~20% (if canopy height only and not vegetation structure is not to be assessed), or ~70% (if vegetation structure is to be assessed).

# %%
import leafmap
chm_map = leafmap.Map(center=(-17.9265, 122.8843), zoom=10, height="600px")
markers = r"Map data\Study locations points.gpkg"
yawuru_area = r"Map data\Yawuru Area.gpkg"
chm_map.add_vector(markers, layer_name="Study Locations")
area_style = {
    "stroke": True,
    "color": "#0000ff",
    "weight": 2,
    "opacity": 1,
    "fill": False,
}
chm_map.add_vector(yawuru_area, layer_name="Yawuru Area", style=area_style)
chm_map
# Out:
# Map(center=[-17.9265, 122.8843], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %% [markdown]
# From the collected lidar data several parameters are determined. The first is canopy height. Zoom in on the map below to see the canopy height maps.

# %%
dir(chm_map)
# Out:
# ['_ENV_VARS',
#  '__add__',
#  '__annotations__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_active_widgets',
#  '_add_layer_editor',
#  '_add_notifiers',
#  '_all_trait_default_generators',
#  '_basemap_metadata',
#  '_call_widget_constructed',
#  '_comm_changed',
#  '_compare',
#  '_control_comm',
#  '_control_ids',
#  '_cross_validation_lock',
#  '_default_dragging_style',
#  '_default_keys',
#  '_default_layers',
#  '_default_options',
#  '_descriptors',
#  '_dom_classes',
#  '_find_widget_of_type',
#  '_fit_bounds',
#  '_gen_repr_from_keys',
#  '_get_embed_state',
#  '_get_trait_default_generator',
#  '_handle_control_comm_msg',
#  '_handle_custom_msg',
#  '_handle_leaflet_event',
#  '_handle_msg',
#  '_holding_sync',
#  '_instance_inits',
#  '_interaction_callbacks',
#  '_is_numpy',
#  '_layer_editor',
#  '_layer_ids',
#  '_layer_manager_widget',
#  '_lock_property',
#  '_log_default',
#  '_model_id',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_msg_callbacks',
#  '_notify_observers',
#  '_notify_trait',
#  '_observe_bounds',
#  '_observe_pixel_bounds',
#  '_property_lock',
#  '_register_validator',
#  '_remove_notifiers',
#  '_repr_keys',
#  '_repr_mimebundle_',
#  '_send',
#  '_should_send_property',
#  '_states_to_send',
#  '_static_immutable_initial_values',
#  '_trait_default_generators',
#  '_trait_from_json',
#  '_trait_notifiers',
#  '_trait_to_json',
#  '_trait_validators',
#  '_trait_values',
#  '_traits',
#  '_validate_controls',
#  '_validate_layers',
#  '_validate_panes',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  '_widget_construction_callback',
#  '_widget_types',
#  'add',
#  'add_basemap',
#  'add_basemap_gui',
#  'add_census_data',
#  'add_circle_markers_from_xy',
#  'add_class',
#  'add_cog_layer',
#  'add_cog_mosaic',
#  'add_cog_mosaic_from_file',
#  'add_colorbar',
#  'add_colormap',
#  'add_control',
#  'add_data',
#  'add_ee_layer',
#  'add_gdf',
#  'add_gdf_from_postgis',
#  'add_geojson',
#  'add_heatmap',
#  'add_html',
#  'add_image',
#  'add_inspector_gui',
#  'add_kml',
#  'add_labels',
#  'add_layer',
#  'add_layer_control',
#  'add_layer_manager',
#  'add_legend',
#  'add_local_tile',
#  'add_marker',
#  'add_marker_cluster',
#  'add_markers',
#  'add_minimap',
#  'add_mosaic_layer',
#  'add_netcdf',
#  'add_nlcd',
#  'add_nlcd_ts',
#  'add_nwi',
#  'add_oam_gui',
#  'add_osm_from_address',
#  'add_osm_from_bbox',
#  'add_osm_from_geocode',
#  'add_osm_from_place',
#  'add_osm_from_point',
#  'add_osm_from_polygon',
#  'add_osm_from_view',
#  'add_planet_by_month',
#  'add_planet_by_quarter',
#  'add_pmtiles',
#  'add_point_layer',
#  'add_points_from_xy',
#  'add_raster',
#  'add_remote_tile',
#  'add_search_control',
#  'add_shp',
#  'add_stac_gui',
#  'add_stac_layer',
#  'add_text',
#  'add_tile_layer',
#  'add_time_slider',
#  'add_title',
#  'add_traits',
#  'add_vector',
#  'add_vector_tile',
#  'add_vector_tile_layer',
#  'add_velocity',
#  'add_widget',
#  'add_wms_layer',
#  'add_xy_data',
#  'add_xyz_service',
#  'api_keys',
#  'attribution_control',
#  'attribution_control_instance',
#  'baseclass',
#  'basemap',
#  'basemap_demo',
#  'batch_edit_lines',
#  'batch_edit_points',
#  'batch_edit_polygons',
#  'blur',
#  'bottom',
#  'bounce_at_zoom_limits',
#  'bounds',
#  'bounds_polygon',
#  'box_zoom',
#  'center',
#  'class_own_trait_events',
#  'class_own_traits',
#  'class_trait_names',
#  'class_traits',
#  'clear',
#  'clear_controls',
#  'clear_drawings',
#  'clear_layers',
#  'close',
#  'close_all',
#  'close_popup_on_click',
#  'comm',
#  'controls',
#  'cross_validation_lock',
#  'crs',
#  'default_style',
#  'double_click_zoom',
#  'dragging',
#  'dragging_style',
#  'draw_control',
#  'draw_features',
#  'east',
#  'edit_lines',
#  'edit_mode',
#  'edit_points',
#  'edit_polygons',
#  'edit_props',
#  'edit_vector',
#  'find_layer',
#  'find_layer_index',
#  'fit_bounds',
#  'focus',
#  'fullscreen',
#  'geojson_layers',
#  'get_bbox',
#  'get_draw_props',
#  'get_layer_names',
#  'get_manager_state',
#  'get_pc_collections',
#  'get_scale',
#  'get_state',
#  'get_view_spec',
#  'handle_comm_opened',
#  'handle_control_comm_opened',
#  'has_trait',
#  'hold_sync',
#  'hold_trait_notifications',
#  'image_overlay',
#  'inertia',
#  'inertia_deceleration',
#  'inertia_max_speed',
#  'interact',
#  'interpolation',
#  'json_layer_dict',
#  'keyboard',
#  'keyboard_pan_offset',
#  'keyboard_zoom_offset',
#  'keys',
#  'layer_control',
#  'layer_opacity',
#  'layer_widget',
#  'layers',
#  'layout',
#  'left',
#  'log',
#  'marker_cluster',
#  'max_zoom',
#  'min_zoom',
#  'model_id',
#  'modisdate',
#  'north',
#  'notify_change',
#  'oam_search',
#  'observe',
#  'observe_attribution_control',
#  'observe_zoom_control',
#  'on_interaction',
#  'on_msg',
#  'on_trait_change',
#  'on_widget_constructed',
#  'open',
#  'options',
#  'panes',
#  'pixel_bounds',
#  'prefer_canvas',
#  'remove',
#  'remove_class',
#  'remove_control',
#  'remove_labels',
#  'remove_layer',
#  'right',
#  'sandbox_path',
#  'save',
#  'save_draw_features',
#  'save_edits',
#  'scroll_wheel_zoom',
#  'search_control',
#  'send',
#  'send_state',
#  'set_catalog_source',
#  'set_center',
#  'set_state',
#  'set_trait',
#  'setup_instance',
#  'south',
#  'split_map',
#  'static_map',
#  'style',
#  'substitute',
#  'substitute_layer',
#  'tabbable',
#  'tap',
#  'tap_tolerance',
#  'to_html',
#  'to_image',
#  'to_streamlit',
#  'tool_output',
#  'tool_output_ctrl',
#  'toolbar',
#  'toolbar_button',
#  'toolbar_reset',
#  'tooltip',
#  'top',
#  'touch_zoom',
#  'trait_defaults',
#  'trait_events',
#  'trait_has_value',
#  'trait_metadata',
#  'trait_names',
#  'trait_values',
#  'traits',
#  'unobserve',
#  'unobserve_all',
#  'update_draw_features',
#  'update_draw_props',
#  'update_layer_manager',
#  'user_roi',
#  'user_roi_bounds',
#  'user_rois',
#  'video_overlay',
#  'west',
#  'widget_types',
#  'widgets',
#  'window_url',
#  'world_copy_jump',
#  'zoom',
#  'zoom_animation_threshold',
#  'zoom_control',
#  'zoom_control_instance',
#  'zoom_delta',
#  'zoom_snap',
#  'zoom_to_bounds',
#  'zoom_to_gdf']

# %%
chm_map.layers
# Out:
# (TileLayer(attribution='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors', base=True, max_zoom=19, min_zoom=1, name='OpenStreetMap', options=['attribution', 'bounds', 'detect_retina', 'max_native_zoom', 'max_zoom', 'min_native_zoom', 'min_zoom', 'no_wrap', 'tile_size', 'tms', 'zoom_offset'], url='https://tile.openstreetmap.org/{z}/{x}/{y}.png'),
#  GeoJSON(data={'type': 'FeatureCollection', 'features': [{'id': '0', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.35783361857254, -17.90849689189429)}, 'bbox': (122.35783361857254, -17.90849689189429, 122.35783361857254, -17.90849689189429)}, {'id': '1', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.3580531990437, -17.865187115819783)}, 'bbox': (122.3580531990437, -17.865187115819783, 122.3580531990437, -17.865187115819783)}, {'id': '2', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.38581127839667, -17.87414664974522)}, 'bbox': (122.38581127839667, -17.87414664974522, 122.38581127839667, -17.87414664974522)}, {'id': '3', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.23028341649656, -17.837013845448663)}, 'bbox': (122.23028341649656, -17.837013845448663, 122.23028341649656, -17.837013845448663)}, {'id': '4', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.54865822680729, -17.772551790172255)}, 'bbox': (122.54865822680729, -17.772551790172255, 122.54865822680729, -17.772551790172255)}, {'id': '5', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.76658191658674, -17.724725470061554)}, 'bbox': (122.76658191658674, -17.724725470061554, 122.76658191658674, -17.724725470061554)}, {'id': '6', 'type': 'Feature', 'properties': {'style': {'weight': 1}}, 'geometry': {'type': 'Point', 'coordinates': (122.9935800364052, -17.74786667907734)}, 'bbox': (122.9935800364052, -17.74786667907734, 122.9935800364052, -17.74786667907734)}], 'bbox': (np.float64(122.23028341649656), np.float64(-17.90849689189429), np.float64(122.9935800364052), np.float64(-17.724725470061554))}, hover_style={'weight': 3, 'fillOpacity': 0, 'color': 'yellow'}, name='Study Locations', style={'weight': 1}),
#  GeoJSON(data={'type': 'FeatureCollection', 'features': [{'id': '0', 'type': 'Feature', 'properties': {'Name': None, 'description': None, 'timestamp': None, 'begin': None, 'end': None, 'altitudeMode': None, 'tessellate': -1, 'extrude': 0, 'visibility': -1, 'drawOrder': None, 'icon': None, 'style': {'stroke': True, 'color': '#0000ff', 'weight': 2, 'opacity': 1, 'fill': False}}, 'geometry': {'type': 'Polygon', 'coordinates': (((122.174395298808, -17.7557692706244), (122.387974738482, -17.7599634071358), (122.39348121063, -17.7105193415662), (123.009219496042, -17.7165720665961), (123.012785025931, -17.8035590959145), (123.160575423722, -17.8103160832479), (123.164546575584, -18.2520576805832), (122.504484387425, -18.1099301541235), (122.440649625885, -17.9920749507333), (122.178591029928, -18.004785193442), (122.174395298808, -17.7557692706244)),)}, 'bbox': (122.174395298808, -18.2520576805832, 123.164546575584, -17.7105193415662)}], 'bbox': (np.float64(122.174395298808), np.float64(-18.2520576805832), np.float64(123.164546575584), np.float64(-17.7105193415662))}, hover_style={'weight': 4, 'fillOpacity': 0, 'color': 'yellow'}, name='Yawuru Area', style={'stroke': True, 'color': '#0000ff', 'weight': 2, 'opacity': 1, 'fill': False}))
